# %% [markdown]
# ##**Essential Imports**

# %%
import json,ast
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## **Reading Files**

# %%
stats_pi_vgg16=ast.literal_eval(open('/content/drive/My Drive/DM Course Project/Transfer Learning Model/TL-PI-VGG16-stats.txt','r').read())
stats_pi_vgg19=ast.literal_eval(open('/content/drive/My Drive/DM Course Project/Transfer Learning Model/TL-PI-VGG19-stats.txt','r').read())
stats_pi_mobilenet=ast.literal_eval(open('/content/drive/My Drive/DM Course Project/Transfer Learning Model/TL-PI-Mobilenet-stats.txt','r').read())
stats_pi_resnet=ast.literal_eval(open('/content/drive/My Drive/DM Course Project/Transfer Learning Model/TL-PI-Resnet50-stats.txt','r').read())
stats_pi_inception=ast.literal_eval(open('/content/drive/My Drive/DM Course Project/Transfer Learning Model/TL-PI-Inceptionv3-stats.txt','r').read())


stats_si_vgg16=ast.literal_eval(open('/content/drive/My Drive/DM Course Project/Transfer Learning Model/TL-SI-VGG16-stats.txt','r').read())
stats_si_vgg19=ast.literal_eval(open('/content/drive/My Drive/DM Course Project/Transfer Learning Model/TL-SI-VGG19-stats.txt','r').read())
stats_si_mobilenet=ast.literal_eval(open('/content/drive/My Drive/DM Course Project/Transfer Learning Model/TL-SI-Mobilenet-stats.txt','r').read())
stats_si_resnet=ast.literal_eval(open('/content/drive/My Drive/DM Course Project/Transfer Learning Model/TL-SI-Resnet50-stats.txt','r').read())
stats_si_inception=ast.literal_eval(open('/content/drive/My Drive/DM Course Project/Transfer Learning Model/TL-SI-Inceptionv3-stats.txt','r').read())

# %% [markdown]
# ## *Considering  20 iterations for all*

# %%
# for i in range(40):
i=19
print("iteration "+str(i+1)+" vgg16: "+str(stats_pi_vgg16['val_accuracy'][i])+" vgg19: "+str(stats_pi_vgg19['val_accuracy'][i])+" mobilenet: "+str(stats_pi_mobilenet['val_accuracy'][i])+" resnet: "+str(stats_pi_resnet['val_accuracy'][i])+" inception: "+str(stats_pi_inception['val_accuracy'][i]))
# Out:
# iteration 20 vgg16: 0.9657142758369446 vgg19: 0.9549999833106995 mobilenet: 0.9435714483261108 resnet: 0.9178571701049805 inception: 0.8514285683631897

# %%
# for i in range(40)
i=19
print("iteration "+str(i+1)+" vgg16: "+str(stats_si_vgg16['val_accuracy'][i])+" vgg19: "+str(stats_si_vgg19['val_accuracy'][i])+" mobilenet: "+str(stats_si_mobilenet['val_accuracy'][i])+" resnet: "+str(stats_si_resnet['val_accuracy'][i])+" inception: "+str(stats_si_inception['val_accuracy'][i]))
# Out:
# iteration 20 vgg16: 0.933571457862854 vgg19: 0.9157142639160156 mobilenet: 0.8485714197158813 resnet: 0.9264285564422607 inception: 0.9549999833106995

# %% [markdown]
# Plot Images table

# %%
i = 19
data = {
    'Model': ['VGG16', 'VGG19', 'MobileNet', 'ResNet50', 'InceptionV3'],
    'Accuracy': [stats_pi_vgg16['val_accuracy'][i], stats_pi_vgg19['val_accuracy'][i], stats_pi_mobilenet['val_accuracy'][i], stats_pi_resnet['val_accuracy'][i], stats_pi_inception['val_accuracy'][i]],
    'Loss': [stats_pi_vgg16['val_loss'][i], stats_pi_vgg19['val_loss'][i], stats_pi_mobilenet['val_loss'][i], stats_pi_resnet['val_loss'][i], stats_pi_inception['val_loss'][i]],
    'MAE': [stats_pi_vgg16['val_mean_absolute_error'][i], stats_pi_vgg19['val_mean_absolute_error'][i], stats_pi_mobilenet['val_mean_absolute_error'][i], stats_pi_resnet['val_mean_absolute_error'][i], stats_pi_inception['val_mean_absolute_error'][i]],
    'MSE': [stats_pi_vgg16['val_mean_squared_error'][i], stats_pi_vgg19['val_mean_squared_error'][i], stats_pi_mobilenet['val_mean_squared_error'][i], stats_pi_resnet['val_mean_squared_error'][i], stats_pi_inception['val_mean_squared_error'][i]],
    'Hinge': [stats_pi_vgg16['val_hinge'][i], stats_pi_vgg19['val_hinge'][i], stats_pi_mobilenet['val_hinge'][i], stats_pi_resnet['val_hinge'][i], stats_pi_inception['val_hinge'][i]],
    'BCE': [stats_pi_vgg16['val_binary_crossentropy'][i], stats_pi_vgg19['val_binary_crossentropy'][i], stats_pi_mobilenet['val_binary_crossentropy'][i], stats_pi_resnet['val_binary_crossentropy'][i], stats_pi_inception['val_binary_crossentropy'][i]]

}

df = pd.DataFrame(data, columns = ['Model', 'Accuracy', 'Loss', 'MAE', 'MSE', 'Hinge','BCE'])
df = df.round(7)

from IPython.display import display, HTML
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Model</th>
#       <th>Accuracy</th>
#       <th>Loss</th>
#       <th>MAE</th>
#       <th>MSE</th>
#       <th>Hinge</th>
#       <th>BCE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>VGG16</td>
#       <td>0.965714</td>
#       <td>0.145587</td>
#       <td>7.253688</td>
#       <td>66.239761</td>
#       <td>0.145158</td>
#       <td>0.390859</td>
#     </tr>
#     <tr>
#       <td>VGG19</td>
#       <td>0.955000</td>
#       <td>0.134147</td>
#       <td>6.217298</td>
#       <td>55.188946</td>
#       <td>0.133510</td>
#       <td>0.531503</td>
#     </tr>
#     <tr>
#       <td>MobileNet</td>
#       <td>0.943571</td>
#       <td>0.132125</td>
#       <td>5.108865</td>
#       <td>33.243992</td>
#       <td>0.131743</td>
#       <td>0.614816</td>
#     </tr>
#     <tr>
#       <td>ResNet50</td>
#       <td>0.917857</td>
#       <td>0.230770</td>
# ...

# %% [markdown]
# Spectrogram Images table

# %%
i = 19
data = {
    'Model': ['VGG16', 'VGG19', 'MobileNet', 'ResNet50', 'InceptionV3'],
    'Accuracy': [stats_si_vgg16['val_accuracy'][i], stats_si_vgg19['val_accuracy'][i], stats_si_mobilenet['val_accuracy'][i], stats_si_resnet['val_accuracy'][i], stats_si_inception['val_accuracy'][i]],
    'Loss': [stats_si_vgg16['val_loss'][i], stats_si_vgg19['val_loss'][i], stats_si_mobilenet['val_loss'][i], stats_si_resnet['val_loss'][i], stats_si_inception['val_loss'][i]],
    'MAE': [stats_si_vgg16['val_mean_absolute_error'][i], stats_si_vgg19['val_mean_absolute_error'][i], stats_si_mobilenet['val_mean_absolute_error'][i], stats_si_resnet['val_mean_absolute_error'][i], stats_si_inception['val_mean_absolute_error'][i]],
    'MSE': [stats_si_vgg16['val_mean_squared_error'][i], stats_si_vgg19['val_mean_squared_error'][i], stats_si_mobilenet['val_mean_squared_error'][i], stats_si_resnet['val_mean_squared_error'][i], stats_si_inception['val_mean_squared_error'][i]],
    'Hinge': [stats_si_vgg16['val_hinge'][i], stats_si_vgg19['val_hinge'][i], stats_si_mobilenet['val_hinge'][i], stats_si_resnet['val_hinge'][i], stats_si_inception['val_hinge'][i]],
    'BCE': [stats_si_vgg16['val_binary_crossentropy'][i], stats_si_vgg19['val_binary_crossentropy'][i], stats_si_mobilenet['val_binary_crossentropy'][i], stats_si_resnet['val_binary_crossentropy'][i], stats_si_inception['val_binary_crossentropy'][i]]

}

df = pd.DataFrame(data, columns = ['Model', 'Accuracy', 'Loss', 'MAE', 'MSE', 'Hinge','BCE'])
df = df.round(7)

from IPython.display import display, HTML
display(HTML(df.to_html(index=False)))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Model</th>
#       <th>Accuracy</th>
#       <th>Loss</th>
#       <th>MAE</th>
#       <th>MSE</th>
#       <th>Hinge</th>
#       <th>BCE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>VGG16</td>
#       <td>0.933571</td>
#       <td>0.195500</td>
#       <td>2.981601</td>
#       <td>16.290995</td>
#       <td>0.194738</td>
#       <td>0.614907</td>
#     </tr>
#     <tr>
#       <td>VGG19</td>
#       <td>0.915714</td>
#       <td>0.176971</td>
#       <td>2.234037</td>
#       <td>8.831971</td>
#       <td>0.175726</td>
#       <td>0.849054</td>
#     </tr>
#     <tr>
#       <td>MobileNet</td>
#       <td>0.848571</td>
#       <td>0.209819</td>
#       <td>3.153695</td>
#       <td>19.936068</td>
#       <td>0.209006</td>
#       <td>1.314585</td>
#     </tr>
#     <tr>
#       <td>ResNet50</td>
#       <td>0.926429</td>
#       <td>0.162888</td>
# ...

# %% [markdown]
# ## **All Parameters**

# %%
print(np.array(stats_pi_inception.keys()))
# Out:
# dict_keys(['loss', 'accuracy', 'mean_absolute_error', 'mean_squared_error', 'hinge', 'binary_crossentropy', 'val_loss', 'val_accuracy', 'val_mean_absolute_error', 'val_mean_squared_error', 'val_hinge', 'val_binary_crossentropy'])

# %% [markdown]
# ## **Comparative Study between different datasets for plot images**

# %%
dataset=['VGG16','VGG19','MobileNet','Resnet50','Inceptionv3']
accuracy=[stats_pi_vgg16['val_accuracy'][19]*100,stats_pi_vgg19['val_accuracy'][19]*100,stats_pi_mobilenet['val_accuracy'][19]*100,stats_pi_resnet['val_accuracy'][19]*100,stats_pi_inception['val_accuracy'][19]*100]
plt.bar(dataset, accuracy, color ='blue',width = 0.4) 
plt.ylim(80,100)
plt.xlabel("Dataset") 
plt.ylabel("Validation accuracy") 
for i, v in enumerate(accuracy):
  plt.text(i-0.25, v+0.35, " "+str(round(v,2)), color='blue', va='center', fontweight='bold')
plt.show()

# %% [markdown]
# ## **Comparative Study between different datasets for Spectogram images**

# %%
dataset=['VGG16','VGG19','MobileNet','Resnet50','Inceptionv3']
accuracy=[stats_si_vgg16['val_accuracy'][19]*100,stats_si_vgg19['val_accuracy'][19]*100,stats_si_mobilenet['val_accuracy'][19]*100,stats_si_resnet['val_accuracy'][19]*100,stats_si_inception['val_accuracy'][19]*100]
plt.bar(dataset, accuracy, color ='blue',width = 0.4) 
plt.ylim(80,100)
plt.xlabel("Dataset") 
plt.ylabel("Validation accuracy") 
for i, v in enumerate(accuracy):
  plt.text(i-0.25, v+0.45, " "+str(round(v,2)), color='blue', va='center', fontweight='bold')
plt.show()

# %% [markdown]
# ## **Comparative Study between PI and SI for VGG16**

# %%
dataset=['Plot Images','Spectogram Images']
accuracy=[stats_pi_vgg16['val_accuracy'][19]*100,stats_si_vgg16['val_accuracy'][19]*100]
plt.bar(dataset, accuracy, color ='blue',width = 0.4) 
plt.ylim(91,100)
plt.xlabel("Preprocessing Method") 
plt.ylabel("Validation accuracy") 
for i, v in enumerate(accuracy):
  plt.text(i-0.1, v+0.25, " "+str(round(v,2)), color='blue', va='center', fontweight='bold')
plt.show()

# %% [markdown]
# ## **Comparative Study between PI and SI for VGG19**

# %%
dataset=['Plot Images','Spectogram Images']
accuracy=[stats_pi_vgg19['val_accuracy'][19]*100,stats_si_vgg19['val_accuracy'][19]*100]
plt.bar(dataset, accuracy, color ='blue',width = 0.4) 
plt.ylim(85,100)
plt.xlabel("Preprocessing Method") 
plt.ylabel("Validation accuracy") 
for i, v in enumerate(accuracy):
  plt.text(i-0.1, v+0.35, " "+str(round(v,2)), color='blue', va='center', fontweight='bold')
plt.show()

# %% [markdown]
# ## **Comparative Study between PI and SI for MobileNet**

# %%
dataset=['Plot Images','Spectogram Images']
accuracy=[stats_pi_mobilenet['val_accuracy'][19]*100,stats_si_mobilenet['val_accuracy'][19]*100]
plt.bar(dataset, accuracy, color ='blue',width = 0.4) 
plt.ylim(80,100)
plt.xlabel("Preprocessing Method") 
plt.ylabel("Validation accuracy") 
for i, v in enumerate(accuracy):
  plt.text(i-0.1, v+0.25, " "+str(round(v,2)), color='blue', va='center', fontweight='bold')
plt.show()

# %% [markdown]
# ## **Comparative Study between PI and SI for Resnet**

# %%
dataset=['Plot Images','Spectogram Images']
accuracy=[stats_pi_resnet['val_accuracy'][19]*100,stats_si_resnet['val_accuracy'][19]*100]
plt.bar(dataset, accuracy, color ='blue',width = 0.4) 
plt.ylim(91,100)
plt.xlabel("Preprocessing Method") 
plt.ylabel("Validation accuracy") 
for i, v in enumerate(accuracy):
  plt.text(i-0.1, v+0.25, " "+str(round(v,2)), color='blue', va='center', fontweight='bold')
plt.show()

# %% [markdown]
# ## **Comparative Study between PI and SI for Inception**

# %%
dataset=['Plot Images','Spectogram Images']
accuracy=[stats_pi_inception['val_accuracy'][19]*100,stats_si_inception['val_accuracy'][19]*100]
plt.bar(dataset, accuracy, color ='blue',width = 0.4) 
plt.ylim(80,100)
plt.xlabel("Preprocessing Method") 
plt.ylabel("Validation accuracy") 
for i, v in enumerate(accuracy):
  plt.text(i-0.1, v+0.25, " "+str(round(v,2)), color='blue', va='center', fontweight='bold')
plt.show()

# %% [markdown]
# ## **TL-PI-VGG16**

# %% [markdown]
# ### Loss vs Iterations

# %%
plt.plot(stats_pi_vgg16['loss'][0:20], label='train loss')
plt.plot(stats_pi_vgg16['val_loss'][0:20], label='test loss')
plt.legend()
plt.ylabel("Loss") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Accuracy vs Iterations

# %%
plt.plot(stats_pi_vgg16['accuracy'][0:20], label='train accuracy')
plt.plot(stats_pi_vgg16['val_accuracy'][0:20], label='test accuracy')
plt.legend()
plt.ylabel("Accuracy") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Absolute Error vs Iterations

# %%
plt.plot(stats_pi_vgg16['mean_absolute_error'][0:20], label='train MAE')
plt.plot(stats_pi_vgg16['val_mean_absolute_error'][0:20], label='test MAE')
plt.legend()
plt.ylabel("MAE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Square Error vs Iterations

# %%
plt.plot(stats_pi_vgg16['mean_squared_error'][0:20], label='train MSE')
plt.plot(stats_pi_vgg16['val_mean_squared_error'][0:20], label='test MSE')
plt.legend()
plt.ylabel("MSE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Hinge vs Iterations

# %%
plt.plot(stats_pi_vgg16['hinge'][0:20], label='train Hinge')
plt.plot(stats_pi_vgg16['val_hinge'][0:20], label='test Hinge')
plt.legend()
plt.ylabel("Hinge") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Binary Cross Entropy vs Iterations

# %%
plt.plot(stats_pi_vgg16['binary_crossentropy'][0:20], label='train BCE')
plt.plot(stats_pi_vgg16['val_binary_crossentropy'][0:20], label='test BCE')
plt.legend()
plt.ylabel("BCE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ## **TL-PI-VGG19**

# %% [markdown]
# ### Loss vs Iterations

# %%
plt.plot(stats_pi_vgg19['loss'][0:20], label='train loss')
plt.plot(stats_pi_vgg19['val_loss'][0:20], label='test loss')
plt.legend()
plt.ylabel("Loss") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Accuracy vs Iterations

# %%
plt.plot(stats_pi_vgg19['accuracy'][0:20], label='train accuracy')
plt.plot(stats_pi_vgg19['val_accuracy'][0:20], label='test accuracy')
plt.legend()
plt.ylabel("Accuracy") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Absolute Error vs Iterations

# %%
plt.plot(stats_pi_vgg19['mean_absolute_error'][0:20], label='train MAE')
plt.plot(stats_pi_vgg19['val_mean_absolute_error'][0:20], label='test MAE')
plt.legend()
plt.ylabel("MAE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Square Error vs Iterations

# %%
plt.plot(stats_pi_vgg19['mean_squared_error'][0:20], label='train MSE')
plt.plot(stats_pi_vgg19['val_mean_squared_error'][0:20], label='test MSE')
plt.legend()
plt.ylabel("MSE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Hinge vs Iterations

# %%
plt.plot(stats_pi_vgg19['hinge'][0:20], label='train Hinge')
plt.plot(stats_pi_vgg19['val_hinge'][0:20], label='test Hinge')
plt.legend()
plt.ylabel("Hinge") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Binary Cross Entropy vs Iterations

# %%
plt.plot(stats_pi_vgg19['binary_crossentropy'][0:20], label='train BCE')
plt.plot(stats_pi_vgg19['val_binary_crossentropy'][0:20], label='test BCE')
plt.legend()
plt.ylabel("BCE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ## **TL-PI-Resnet**

# %% [markdown]
# ### Loss vs Iterations

# %%
plt.plot(stats_pi_resnet['loss'][0:20], label='train loss')
plt.plot(stats_pi_resnet['val_loss'][0:20], label='test loss')
plt.legend()
plt.ylabel("Loss") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Accuracy vs Iterations

# %%
plt.plot(stats_pi_resnet['accuracy'][0:20], label='train accuracy')
plt.plot(stats_pi_resnet['val_accuracy'][0:20], label='test accuracy')
plt.legend()
plt.ylabel("Accuracy") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Absolute Error vs Iterations

# %%
plt.plot(stats_pi_resnet['mean_absolute_error'][0:20], label='train MAE')
plt.plot(stats_pi_resnet['val_mean_absolute_error'][0:20], label='test MAE')
plt.legend()
plt.ylabel("MAE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Square Error vs Iterations

# %%
plt.plot(stats_pi_resnet['mean_squared_error'][0:20], label='train MSE')
plt.plot(stats_pi_resnet['val_mean_squared_error'][0:20], label='test MSE')
plt.legend()
plt.ylabel("MSE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Hinge vs Iterations

# %%
plt.plot(stats_pi_resnet['hinge'][0:20], label='train Hinge')
plt.plot(stats_pi_resnet['val_hinge'][0:20], label='test Hinge')
plt.legend()
plt.ylabel("Hinge") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Binary Cross Entropy vs Iterations

# %%
plt.plot(stats_pi_resnet['binary_crossentropy'][0:20], label='train BCE')
plt.plot(stats_pi_resnet['val_binary_crossentropy'][0:20], label='test BCE')
plt.legend()
plt.ylabel("BCE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ## **TL-PI-Inception**

# %% [markdown]
# ### Loss vs Iterations

# %%
plt.plot(stats_pi_inception['loss'][0:20], label='train loss')
plt.plot(stats_pi_inception['val_loss'][0:20], label='test loss')
plt.legend()
plt.ylabel("Loss") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Accuracy vs Iterations

# %%
plt.plot(stats_pi_inception['accuracy'][0:20], label='train accuracy')
plt.plot(stats_pi_inception['val_accuracy'][0:20], label='test accuracy')
plt.legend()
plt.ylabel("Accuracy") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Absolute Error vs Iterations

# %%
plt.plot(stats_pi_inception['mean_absolute_error'][0:20], label='train MAE')
plt.plot(stats_pi_inception['val_mean_absolute_error'][0:20], label='test MAE')
plt.legend()
plt.ylabel("MAE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Square Error vs Iterations

# %%
plt.plot(stats_pi_inception['mean_squared_error'][0:20], label='train MSE')
plt.plot(stats_pi_inception['val_mean_squared_error'][0:20], label='test MSE')
plt.legend()
plt.ylabel("MSE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Hinge vs Iterations

# %%
plt.plot(stats_pi_inception['hinge'][0:20], label='train Hinge')
plt.plot(stats_pi_inception['val_hinge'][0:20], label='test Hinge')
plt.legend()
plt.ylabel("Hinge") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Binary Cross Entropy vs Iterations

# %%
plt.plot(stats_pi_inception['binary_crossentropy'][0:20], label='train BCE')
plt.plot(stats_pi_inception['val_binary_crossentropy'][0:20], label='test BCE')
plt.legend()
plt.ylabel("BCE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ## **TL-PI-Mobilenet**

# %% [markdown]
# ### Loss vs Iterations

# %%
plt.plot(stats_pi_mobilenet['loss'][0:20], label='train loss')
plt.plot(stats_pi_mobilenet['val_loss'][0:20], label='test loss')
plt.legend()
plt.ylabel("Loss") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Accuracy vs Iterations

# %%
plt.plot(stats_pi_mobilenet['accuracy'][0:20], label='train accuracy')
plt.plot(stats_pi_mobilenet['val_accuracy'][0:20], label='test accuracy')
plt.legend()
plt.ylabel("Accuracy") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Absolute Error vs Iterations

# %%
plt.plot(stats_pi_mobilenet['mean_absolute_error'][0:20], label='train MAE')
plt.plot(stats_pi_mobilenet['val_mean_absolute_error'][0:20], label='test MAE')
plt.legend()
plt.ylabel("MAE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Square Error vs Iterations

# %%
plt.plot(stats_pi_mobilenet['mean_squared_error'][0:20], label='train MSE')
plt.plot(stats_pi_mobilenet['val_mean_squared_error'][0:20], label='test MSE')
plt.legend()
plt.ylabel("MSE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Hinge vs Iterations

# %%
plt.plot(stats_pi_mobilenet['hinge'][0:20], label='train Hinge')
plt.plot(stats_pi_mobilenet['val_hinge'][0:20], label='test Hinge')
plt.legend()
plt.ylabel("Hinge") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Binary Cross Entropy vs Iterations

# %%
plt.plot(stats_pi_mobilenet['binary_crossentropy'][0:20], label='train BCE')
plt.plot(stats_pi_mobilenet['val_binary_crossentropy'][0:20], label='test BCE')
plt.legend()
plt.ylabel("BCE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ## **TL-SI-VGG16**

# %% [markdown]
# ### Loss vs Iterations

# %%
plt.plot(stats_si_vgg16['loss'][0:20], label='train loss')
plt.plot(stats_si_vgg16['val_loss'][0:20], label='test loss')
plt.legend()
plt.ylabel("Loss") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Accuracy vs Iterations

# %%
plt.plot(stats_si_vgg16['accuracy'][0:20], label='train accuracy')
plt.plot(stats_si_vgg16['val_accuracy'][0:20], label='test accuracy')
plt.legend()
plt.ylabel("Accuracy") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Absolute Error vs Iterations

# %%
plt.plot(stats_si_vgg16['mean_absolute_error'][0:20], label='train MAE')
plt.plot(stats_si_vgg16['val_mean_absolute_error'][0:20], label='test MAE')
plt.legend()
plt.ylabel("MAE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Square Error vs Iterations

# %%
plt.plot(stats_si_vgg16['mean_squared_error'][0:20], label='train MSE')
plt.plot(stats_si_vgg16['val_mean_squared_error'][0:20], label='test MSE')
plt.legend()
plt.ylabel("MSE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Hinge vs Iterations

# %%
plt.plot(stats_si_vgg16['hinge'][0:20], label='train Hinge')
plt.plot(stats_si_vgg16['val_hinge'][0:20], label='test Hinge')
plt.legend()
plt.ylabel("Hinge") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Binary Cross Entropy vs Iterations

# %%
plt.plot(stats_si_vgg16['binary_crossentropy'][0:20], label='train BCE')
plt.plot(stats_si_vgg16['val_binary_crossentropy'][0:20], label='test BCE')
plt.legend()
plt.ylabel("BCE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ## **TL-SI-VGG19**

# %% [markdown]
# ### Loss vs Iterations

# %%
plt.plot(stats_si_vgg19['loss'][0:20], label='train loss')
plt.plot(stats_si_vgg19['val_loss'][0:20], label='test loss')
plt.legend()
plt.ylabel("Loss") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Accuracy vs Iterations

# %%
plt.plot(stats_si_vgg19['accuracy'][0:20], label='train accuracy')
plt.plot(stats_si_vgg19['val_accuracy'][0:20], label='test accuracy')
plt.legend()
plt.ylabel("Accuracy") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Absolute Error vs Iterations

# %%
plt.plot(stats_si_vgg19['mean_absolute_error'][0:20], label='train MAE')
plt.plot(stats_si_vgg19['val_mean_absolute_error'][0:20], label='test MAE')
plt.legend()
plt.ylabel("MAE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Square Error vs Iterations

# %%
plt.plot(stats_si_vgg19['mean_squared_error'][0:20], label='train MSE')
plt.plot(stats_si_vgg19['val_mean_squared_error'][0:20], label='test MSE')
plt.legend()
plt.ylabel("MSE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Hinge vs Iterations

# %%
plt.plot(stats_si_vgg19['hinge'][0:20], label='train Hinge')
plt.plot(stats_si_vgg19['val_hinge'][0:20], label='test Hinge')
plt.legend()
plt.ylabel("Hinge") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Binary Cross Entropy vs Iterations

# %%
plt.plot(stats_si_vgg19['binary_crossentropy'][0:20], label='train BCE')
plt.plot(stats_si_vgg19['val_binary_crossentropy'][0:20], label='test BCE')
plt.legend()
plt.ylabel("BCE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ## **TL-SI-Resnet**

# %% [markdown]
# ### Loss vs Iterations

# %%
plt.plot(stats_si_resnet['loss'][0:20], label='train loss')
plt.plot(stats_si_resnet['val_loss'][0:20], label='test loss')
plt.legend()
plt.ylabel("Loss") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Accuracy vs Iterations

# %%
plt.plot(stats_si_resnet['accuracy'][0:20], label='train accuracy')
plt.plot(stats_si_resnet['val_accuracy'][0:20], label='test accuracy')
plt.legend()
plt.ylabel("Accuracy") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Absolute Error vs Iterations

# %%
plt.plot(stats_si_resnet['mean_absolute_error'][0:20], label='train MAE')
plt.plot(stats_si_resnet['val_mean_absolute_error'][0:20], label='test MAE')
plt.legend()
plt.ylabel("MAE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Square Error vs Iterations

# %%
plt.plot(stats_si_resnet['mean_squared_error'][0:20], label='train MSE')
plt.plot(stats_si_resnet['val_mean_squared_error'][0:20], label='test MSE')
plt.legend()
plt.ylabel("MSE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Hinge vs Iterations

# %%
plt.plot(stats_si_resnet['hinge'][0:20], label='train Hinge')
plt.plot(stats_si_resnet['val_hinge'][0:20], label='test Hinge')
plt.legend()
plt.ylabel("Hinge") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Binary Cross Entropy vs Iterations

# %%
plt.plot(stats_si_resnet['binary_crossentropy'][0:20], label='train BCE')
plt.plot(stats_si_resnet['val_binary_crossentropy'][0:20], label='test BCE')
plt.legend()
plt.ylabel("BCE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ## **TL-SI-Inception**

# %% [markdown]
# ### Loss vs Iterations

# %%
plt.plot(stats_si_inception['loss'][0:20], label='train loss')
plt.plot(stats_si_inception['val_loss'][0:20], label='test loss')
plt.legend()
plt.ylabel("Loss") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Accuracy vs Iterations

# %%
plt.plot(stats_si_inception['accuracy'][0:20], label='train accuracy')
plt.plot(stats_si_inception['val_accuracy'][0:20], label='test accuracy')
plt.legend()
plt.ylabel("Accuracy") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Absolute Error vs Iterations

# %%
plt.plot(stats_si_inception['mean_absolute_error'][0:20], label='train MAE')
plt.plot(stats_si_inception['val_mean_absolute_error'][0:20], label='test MAE')
plt.legend()
plt.ylabel("MAE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Square Error vs Iterations

# %%
plt.plot(stats_si_inception['mean_squared_error'][0:20], label='train MSE')
plt.plot(stats_si_inception['val_mean_squared_error'][0:20], label='test MSE')
plt.legend()
plt.ylabel("MSE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Hinge vs Iterations

# %%
plt.plot(stats_si_inception['hinge'][0:20], label='train Hinge')
plt.plot(stats_si_inception['val_hinge'][0:20], label='test Hinge')
plt.legend()
plt.ylabel("Hinge") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Binary Cross Entropy vs Iterations

# %%
plt.plot(stats_si_inception['binary_crossentropy'][0:20], label='train BCE')
plt.plot(stats_si_inception['val_binary_crossentropy'][0:20], label='test BCE')
plt.legend()
plt.ylabel("BCE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ## **TL-SI-Mobilenet**

# %% [markdown]
# ### Loss vs Iterations

# %%
plt.plot(stats_si_mobilenet['loss'][0:20], label='train loss')
plt.plot(stats_si_mobilenet['val_loss'][0:20], label='test loss')
plt.legend()
plt.ylabel("Loss") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Accuracy vs Iterations

# %%
plt.plot(stats_si_mobilenet['accuracy'][0:20], label='train accuracy')
plt.plot(stats_si_mobilenet['val_accuracy'][0:20], label='test accuracy')
plt.legend()
plt.ylabel("Accuracy") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Absolute Error vs Iterations

# %%
plt.plot(stats_si_mobilenet['mean_absolute_error'][0:20], label='train MAE')
plt.plot(stats_si_mobilenet['val_mean_absolute_error'][0:20], label='test MAE')
plt.legend()
plt.ylabel("MAE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Mean Square Error vs Iterations

# %%
plt.plot(stats_si_mobilenet['mean_squared_error'][0:20], label='train MSE')
plt.plot(stats_si_mobilenet['val_mean_squared_error'][0:20], label='test MSE')
plt.legend()
plt.ylabel("MSE") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Hinge vs Iterations

# %%
plt.plot(stats_si_mobilenet['hinge'][0:20], label='train Hinge')
plt.plot(stats_si_mobilenet['val_hinge'][0:20], label='test Hinge')
plt.legend()
plt.ylabel("Hinge") 
plt.xlabel("Iterations") 
plt.show()

# %% [markdown]
# ### Binary Cross Entropy vs Iterations

# %%
plt.plot(stats_si_mobilenet['binary_crossentropy'][0:20], label='train BCE')
plt.plot(stats_si_mobilenet['val_binary_crossentropy'][0:20], label='test BCE')
plt.legend()
plt.ylabel("BCE") 
plt.xlabel("Iterations") 
plt.show()
